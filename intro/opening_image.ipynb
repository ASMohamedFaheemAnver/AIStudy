# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread("puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (224, 300, 3)

# %%
# Matplotlib -> RGB and OpenCV -> BGR
plt.imshow(img)

# %%
fixed_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_img)

# %%
img_gray = cv2.imread("puppy.jpg", cv2.IMREAD_GRAYSCALE)
img_gray.shape
# Out:
# (224, 300)

# %%
plt.imshow(img_gray, cmap="gray")

# %%
fixed_img.shape
# Out:
# (224, 300, 3)

# %%
new_img = cv2.resize(fixed_img, (112, 150))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img2 = cv2.resize(fixed_img, (0, 0), fixed_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img2)

# %%
new_img2.shape
# Out:
# (112, 150, 3)

# %%
new_img3 = cv2.flip(fixed_img, 0)
plt.imshow(new_img3)

# %%
new_img3 = cv2.flip(fixed_img, 1)
plt.imshow(new_img3)

# %%
cv2.imwrite("opened_img_by_opencv.jpg", img)
# Out:
# True

# %%
fig = plt.figure(figsize)
