# %%
import sys

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

pic = Image.open("./intro/puppy.jpg")

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x224 at 0x7F9F4ADA2710>

# %%
pic_arr = np.asarray(pic)
print(pic_arr.shape)
# Out:
# (224, 300, 3)

# %%
pic_red = pic_arr.copy()

# %%
print(pic_red.shape)
# Out:
# (224, 300, 3)

# %%
plt.imshow(pic_red[:, :, 0], cmap="gray")

# %%
plt.imshow(pic_red[:, :, 1], cmap="gray")

# %%
plt.imshow(pic_red[:, :, 2], cmap="gray")

# %%
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,2] = 0
plt.imshow(pic_red)
